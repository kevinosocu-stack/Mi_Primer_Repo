# %% [markdown]
# # Juego numero mágico
# ## Kevin Socu 2025

# %%
import numpy as np
print("""
Bienvenido a el numero magico, tienes que adivinar el numero que esta pensando la computadora.
La computadora pensara en un numero del 1 al 100, y tu tienes que adivinarlo.
Si aciertas, ganas el juego.
Si fallas, la computadora te dira si el numero es mayor o menor al que eligio
Solo tienes 6 vidas, asi que elige con cuidado.
Elige la dificultad:
    1. Facil (Numero del 1 al 25)
    2. Medio (Numero del 1 al 50)
    3. Dificil (Numero del 1 al 100)
""")

dificultad = int(input("Elige la dificultad:"))

while dificultad not in [1, 2, 3]:
    print("Dificultad no valida, reingresa la dificultad")
    dificultad = int(input("Elige la dificultad:"))
if dificultad == 1:
        cpu = np.random.randint(1,26)
        dificultad = "Facil"
        
elif dificultad == 2:
        cpu = np.random.randint(1,51)
        dificultad = "Medio"

elif dificultad == 3:
        cpu = np.random.randint(1,101)
        dificultad = "Dificil"

print("Elegiste la dificultad", dificultad)

def mayor(vidas):
    print("El numero es mayor que", (numero_usuario))
    print("Te quedan", (vidas), "vidas")

def menor(vidas):
    print("El numero es menor que", (numero_usuario))
    print("Te quedan", (vidas), "vidas")

def no_vidas ():
    print("Se te acabaron las vidas", "el numero era", cpu)
    

ya_ganador = False
vidas = 6


while not ya_ganador:
    numero_usuario = int(input("Adivina el numero que esta pensando la computadora:"))
    
    
    if numero_usuario > cpu:
        vidas = vidas - 1
        mayor(vidas)

        
        if vidas == 0:
            no_vidas()
            ya_ganador = True
        
    elif numero_usuario < cpu:
        vidas = vidas - 1
        menor(vidas)

        
        if vidas == 0:
            no_vidas()
            ya_ganador = True

    else:
        print("¡¡¡¡Adivinaste!!!!!")
        ya_ganador = True
# Out:
# Bienvenido a el numero magico, tienes que adivinar el numero que esta pensando la computadora.
# La computadora pensara en un numero del 1 al 100, y tu tienes que adivinarlo.
# Si aciertas, ganas el juego.
# Si fallas, la computadora te dira si el numero es mayor o menor al que eligio
# Solo tienes 6 vidas, asi que elige con cuidado.
# Elige la dificultad:
#     1. Facil (Numero del 1 al 25)
#     2. Medio (Numero del 1 al 50)
#     3. Dificil (Numero del 1 al 100)
#
# Elegiste la dificultad Medio
# El numero es menor que 25
# Te quedan 5 vidas
# El numero es menor que 12
# Te quedan 5 vidas
# El numero es menor que 6
# Te quedan 5 vidas
# El numero es menor que 5
# Te quedan 5 vidas
# El numero es menor que 4
# Te quedan 5 vidas
# El numero es menor que 3
# Te quedan 5 vidas
# El numero es menor que 2
# Te quedan 5 vidas
# El numero es menor que 1
# Te quedan 5 vidas
# El numero es menor que 0
# Te quedan 5 vidas
# ...
